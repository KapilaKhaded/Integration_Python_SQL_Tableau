# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dfCorona = pd.read_html('file:///Users/kapilakhaded/GIT/Corona_Virus_Analysis/Coronavirus%20Update%20(Live):%201,827,144%20Cases%20and%20112,410%20Deaths%20from%20COVID-19%20Virus%20Pandemic%20-%20Worldom.webarchive')

# %%
dfCor = dfCorona[0]

# %%
#Remove first row for world count
dfCor = dfCor.drop(0,axis=0)
dfCor
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-133a69a10bf4> in <module>
# ----> 1 dfCor = dfCor.drop(0,axis=0)
#       2 dfCor
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
dfCor['TotalCases'].head(10).plot.kde()

# %%
dfCor.head(10).plot.scatter(x='TotalDeaths',y='TotalCases')

# %%
dfCor['TotalCases']
# Out:
# 0                      World
# 1                        USA
# 2                      Spain
# 3                      Italy
# 4                     France
#                ...
# 209         Papua New Guinea
# 210              Timor-Leste
# 211    Saint Pierre Miquelon
# 212                    Yemen
# 213                   Total:
# Name: Country,Other, Length: 214, dtype: object

# %% [markdown]
# # Create Figure (empty canvas)
# fig = plt.figure()
#
# # Add set of axes to figure
# axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)
#
# # Plot on that set of axes
# axes.plot(dfCor['Country,Other'].head(10), dfCor['TotalCases'].head(10), 'b')
# #axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
# #axes.set_ylabel('Set y Label')
# #axes.set_title('Set Title')

# %%
#plt.hist2d(dfCor['Country,Other'].head(10), dfCor['TotalCases'].head(10))
dfCor.head(20).plot.bar('Country,Other', 'TotalCases')

# %%
dfCor['TotalCases'].head(10)
# Out:
# 1     545827
# 2     166019
# 3     156363
# 4     129654
# 5     126656
# 6      84279
# 7      82052
# 8      71686
# 9      56956
# 10     29647
# Name: TotalCases, dtype: int64
